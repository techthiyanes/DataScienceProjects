# %%
#Importing the libraries
import numpy as np
import pandas as pd

# %%
#Read the file
data = pd.read_csv("C:/Users/Thiyaneswaran_Manoha/Downloads/Notebooks/Notebooks/Wholesale customers data.csv")
data.head()
# Out:
#    Buyer/Spender Channel Region  Fresh  Milk  Grocery  Frozen  \
# 0              1  Retail  Other  12669  9656     7561     214
# 1              2  Retail  Other   7057  9810     9568    1762
# 2              3  Retail  Other   6353  8808     7684    2405
# 3              4   Hotel  Other  13265  1196     4221    6404
# 4              5  Retail  Other  22615  5410     7198    3915
#
#    Detergents_Paper  Delicatessen
# 0              2674          1338
# 1              3293          1776
# 2              3516          7844
# 3               507          1788
# 4              1777          5185

# %%
#Covariance
data.cov()
# Out:
#                   Buyer/Spender         Fresh          Milk       Grocery  \
# Buyer/Spender      16170.000000 -9.834538e+04 -1.523089e+05 -1.697961e+05
# Fresh             -98345.376993  1.599549e+08  9.381789e+06 -1.424713e+06
# Milk             -152308.887244  9.381789e+06  5.446997e+07  5.108319e+07
# Grocery          -169796.066059 -1.424713e+06  5.108319e+07  9.031010e+07
# Frozen             33213.227790  2.123665e+07  4.442612e+06 -1.854282e+06
# Detergents_Paper  -81463.855353 -6.147826e+06  2.328834e+07  4.189519e+07
# Delicatessen      -36522.381549  8.727310e+06  8.457925e+06  5.507291e+06
#
#                         Frozen  Detergents_Paper  Delicatessen
# Buyer/Spender     3.321323e+04     -8.146386e+04 -3.652238e+04
# Fresh             2.123665e+07     -6.147826e+06  8.727310e+06
# Milk              4.442612e+06      2.328834e+07  8.457925e+06
# Grocery          -1.854282e+06      4.189519e+07  5.507291e+06
# ...

# %%
#Information About the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 9 columns):
# Buyer/Spender       440 non-null int64
# Channel             440 non-null object
# Region              440 non-null object
# Fresh               440 non-null int64
# Milk                440 non-null int64
# Grocery             440 non-null int64
# Frozen              440 non-null int64
# Detergents_Paper    440 non-null int64
# Delicatessen        440 non-null int64
# dtypes: int64(7), object(2)
# memory usage: 31.0+ KB

# %%
# Display a brief description of the overall dataset
data.describe(include='all')
# Out:
#         Buyer/Spender Channel Region          Fresh          Milk  \
# count      440.000000     440    440     440.000000    440.000000
# unique            NaN       2      3            NaN           NaN
# top               NaN   Hotel  Other            NaN           NaN
# freq              NaN     298    316            NaN           NaN
# mean       220.500000     NaN    NaN   12000.297727   5796.265909
# std        127.161315     NaN    NaN   12647.328865   7380.377175
# min          1.000000     NaN    NaN       3.000000     55.000000
# 25%        110.750000     NaN    NaN    3127.750000   1533.000000
# 50%        220.500000     NaN    NaN    8504.000000   3627.000000
# 75%        330.250000     NaN    NaN   16933.750000   7190.250000
# max        440.000000     NaN    NaN  112151.000000  73498.000000
#
#              Grocery        Frozen  Detergents_Paper  Delicatessen
# count     440.000000    440.000000        440.000000    440.000000
# ...

# %%
# Check for missing value in any colum
data.isnull().sum()
# Out:
# Buyer/Spender       0
# Channel             0
# Region              0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicatessen        0
# dtype: int64

# %%
#Statistical Metrics
data.describe().T
# Out:
#                   count          mean           std   min      25%     50%  \
# Buyer/Spender     440.0    220.500000    127.161315   1.0   110.75   220.5
# Fresh             440.0  12000.297727  12647.328865   3.0  3127.75  8504.0
# Milk              440.0   5796.265909   7380.377175  55.0  1533.00  3627.0
# Grocery           440.0   7951.277273   9503.162829   3.0  2153.00  4755.5
# Frozen            440.0   3071.931818   4854.673333  25.0   742.25  1526.0
# Detergents_Paper  440.0   2881.493182   4767.854448   3.0   256.75   816.5
# Delicatessen      440.0   1524.870455   2820.105937   3.0   408.25   965.5
#
#                        75%       max
# Buyer/Spender       330.25     440.0
# Fresh             16933.75  112151.0
# Milk               7190.25   73498.0
# Grocery           10655.75   92780.0
# Frozen             3554.25   60869.0
# Detergents_Paper   3922.00   40827.0
# Delicatessen       1820.25   47943.0

# %%
#Outlier count
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1
print("IQR \n",IQR)
print(((data < (Q1 - 1.5 * IQR)) | (data > (Q3 + 1.5 * IQR))).sum())
# Out:
# IQR
#  Buyer/Spender         219.50
# Fresh               13806.00
# Milk                 5657.25
# Grocery              8502.75
# Frozen               2812.00
# Detergents_Paper     3665.25
# Delicatessen         1412.00
# dtype: float64
# Buyer/Spender        0
# Channel              0
# Delicatessen        27
# Detergents_Paper    30
# Fresh               20
# Frozen              43
# Grocery             24
# Milk                28
# Region               0
# dtype: int64

# %%
#CV
def coefficientOfVariation(data): 
    return (data.std() /data.mean())

print(coefficientOfVariation(data))
# Out:
# Buyer/Spender       0.576695
# Fresh               1.053918
# Milk                1.273299
# Grocery             1.195174
# Frozen              1.580332
# Detergents_Paper    1.654647
# Delicatessen        1.849407
# dtype: float64

# %%
from scipy.stats import variation
print("coefficient of variation at Buyer spender is",variation(data.iloc[:,0]))
for i in range(3,len(data.columns)):
    print ("coefficient of variation at "+data.columns.values[i]+" is", variation(data.iloc[:,i]))
# Out:
# coefficient of variation at Buyer spender is 0.5760395971944144
# coefficient of variation at Fresh is 1.0527196084948243
# coefficient of variation at Milk is 1.27185083074245
# coefficient of variation at Grocery is 1.1938154477492668
# coefficient of variation at Frozen is 1.578535529860776
# coefficient of variation at Detergents_Paper is 1.6527657881041735
# coefficient of variation at Delicatessen is 1.8473041039189302

# %%
#Plots to see the distribution of the continuous features individually
data.hist(figsize=(20,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022FDEB79470>,
# ...
#       dtype=object)

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
import scipy.stats as stats
from sklearn.preprocessing import LabelEncoder
import copy

# %%
#Skewness a measure of the asymmetry of the probability distribution of a real-valued random variable about its mean.
data.skew(axis = 0, skipna = True)
# Out:
# Buyer/Spender        0.000000
# Fresh                2.561323
# Milk                 4.053755
# Grocery              3.587429
# Frozen               5.907986
# Detergents_Paper     3.631851
# Delicatessen        11.151586
# dtype: float64

# %%
# kurtosis - a measure of the "tailedness" of the probability distribution of a real-valued random variable
data.kurt(axis = 0,skipna = True)
# Out:
# Buyer/Spender        -1.200000
# Fresh                11.536408
# Milk                 24.669398
# Grocery              20.914670
# Frozen               54.689281
# Detergents_Paper     19.009464
# Delicatessen        170.694939
# dtype: float64

# %%
#pivot table
table = pd.pivot_table(data,index =['Region'], 
                         columns =['Channel'], aggfunc = np.size)
table
# Out:
#         Buyer/Spender        Delicatessen        Detergents_Paper         \
# Channel         Hotel Retail        Hotel Retail            Hotel Retail
# Region
# Lisbon             59     18           59     18               59     18
# Oporto             28     19           28     19               28     19
# Other             211    105          211    105              211    105
#
#         Fresh        Frozen        Grocery         Milk
# Channel Hotel Retail  Hotel Retail   Hotel Retail Hotel Retail
# Region
# Lisbon     59     18     59     18      59     18    59     18
# Oporto     28     19     28     19      28     19    28     19
# Other     211    105    211    105     211    105   211    105

# %%
#Grouby Region with Channel
data.groupby('Region').aggregate({'Region':np.size, 'Channel':np.size})
# Out:
#         Region  Channel
# Region
# Lisbon      77       77
# Oporto      47       47
# Other      316      316

# %%
data.groupby(['Region','Channel']).aggregate({'Region':np.size, 'Channel':np.size})
# Out:
#                 Region  Channel
# Region Channel
# Lisbon Hotel        59       59
#        Retail       18       18
# Oporto Hotel        28       28
#        Retail       19       19
# Other  Hotel       211      211
#        Retail      105      105

# %%
#Cross Tab
pd.crosstab(data['Region'],data['Channel'] )
# Out:
# Channel  Hotel  Retail
# Region
# Lisbon      59      18
# Oporto      28      19
# Other      211     105

# %%
import seaborn as sns

# %%
#Pairplot
sns.pairplot(data)

# %%
#Pivot table - Enite table wrt channel
table2=pd.pivot_table(data,values=['Fresh','Milk','Grocery','Frozen','Detergents_Paper','Delicatessen'],index =['Region'], 
                         columns =['Channel'], aggfunc={'Fresh':[np.size,np.sum],
                                                        'Milk': [np.size,np.sum],
                                                        'Grocery':[np.size,np.sum],
                                                        'Frozen':[np.size,np.sum],
                                                       'Detergents_Paper':[np.size,np.sum],
                                                        'Delicatessen':[np.size,np.sum]})
pd.set_option('display.max_columns',60)
table2
# Out:
#         Delicatessen                        Detergents_Paper                 \
#                 size            sum                     size            sum
# Channel        Hotel Retail   Hotel  Retail            Hotel Retail   Hotel
# Region
# Lisbon            59     18   70632   33695               59     18   56081
# Oporto            28     19   30965   23541               28     19   13516
# Other            211    105  320358  191752              211    105  165990
#
#                 Fresh                          Frozen                         \
#                  size             sum            size            sum
# Channel  Retail Hotel Retail    Hotel   Retail  Hotel Retail   Hotel  Retail
# Region
# Lisbon   148055    59     18   761233    93600     59     18  184512   46514
# Oporto   159795    28     19   326215   138506     28     19  160861   29271
# Other    724420   211    105  2928269  1032308    211    105  771606  158886
#
# ...

# %%
#Pivot table - Enite table wrt channel
table3=pd.pivot_table(data,values=['Fresh','Milk','Grocery','Frozen','Detergents_Paper','Delicatessen'],index =['Region','Channel'], 
                                                aggfunc={'Fresh':[np.size,np.sum],
                                                        'Milk': [np.size,np.sum],
                                                        'Grocery':[np.size,np.sum],
                                                        'Frozen':[np.size,np.sum],
                                                       'Detergents_Paper':[np.size,np.sum],
                                                        'Delicatessen':[np.size,np.sum]})
table3
# Out:
#                Delicatessen         Detergents_Paper         Fresh           \
#                        size     sum             size     sum  size      sum
# Region Channel
# Lisbon Hotel             59   70632               59   56081    59   761233
#        Retail            18   33695               18  148055    18    93600
# Oporto Hotel             28   30965               28   13516    28   326215
#        Retail            19   23541               19  159795    19   138506
# Other  Hotel            211  320358              211  165990   211  2928269
#        Retail           105  191752              105  724420   105  1032308
#
#                Frozen         Grocery          Milk
#                  size     sum    size      sum size      sum
# Region Channel
# Lisbon Hotel       59  184512      59   237542   59   228342
#        Retail      18   46514      18   332495   18   194112
# Oporto Hotel       28  160861      28   123074   28    64519
# ...

# %%
#Pivot table - Enite table wrt channel
table4=pd.pivot_table(data,values=['Fresh','Milk','Grocery','Frozen','Detergents_Paper','Delicatessen'],index =['Channel','Region'], 
                                                aggfunc={'Fresh':[np.sum],
                                                        'Milk': [np.sum],
                                                        'Grocery':[np.sum],
                                                        'Frozen':[np.sum],
                                                       'Detergents_Paper':[np.sum],
                                                        'Delicatessen':[np.sum]})
table4
# Out:
#                Delicatessen Detergents_Paper    Fresh  Frozen  Grocery  \
#                         sum              sum      sum     sum      sum
# Channel Region
# Hotel   Lisbon        70632            56081   761233  184512   237542
#         Oporto        30965            13516   326215  160861   123074
#         Other        320358           165990  2928269  771606   820101
# Retail  Lisbon        33695           148055    93600   46514   332495
#         Oporto        23541           159795   138506   29271   310200
#         Other        191752           724420  1032308  158886  1675150
#
#                    Milk
#                     sum
# Channel Region
# Hotel   Lisbon   228342
#         Oporto    64519
#         Other    735753
# Retail  Lisbon   194112
#         Oporto   174625
#         Other   1153006

# %%
grpbydf=data.groupby(['Channel','Region']).aggregate({'Fresh':[np.sum], 'Milk':[np.sum],'Grocery':[np.sum],'Frozen':[np.sum],'Detergents_Paper':[np.sum],'Delicatessen':[np.sum]})
print(grpbydf)
grpbydf.to_csv('D:/GL/SWDMAssignmentFinal/grpdata.csv')
grpdata=pd.read_csv('D:/GL/SWDMAssignmentFinal/grpdata.csv')
grpdata
# Out:
#                   Fresh     Milk  Grocery  Frozen Detergents_Paper  \
#                     sum      sum      sum     sum              sum
# Channel Region
# Hotel   Lisbon   761233   228342   237542  184512            56081
#         Oporto   326215    64519   123074  160861            13516
#         Other   2928269   735753   820101  771606           165990
# Retail  Lisbon    93600   194112   332495   46514           148055
#         Oporto   138506   174625   310200   29271           159795
#         Other   1032308  1153006  1675150  158886           724420
#
#                Delicatessen
#                         sum
# Channel Region
# Hotel   Lisbon        70632
#         Oporto        30965
#         Other        320358
# Retail  Lisbon        33695
#         Oporto        23541
#         Other        191752
#   Unnamed: 0 Unnamed: 1    Fresh     Milk  Grocery  Frozen Detergents_Paper  \
# 0        NaN        NaN      sum      sum      sum     sum              sum
# ...

# %%
dropgrpdf=grpdata.drop(grpdata.index[:2])
dropgrpdf
# Out:
#   Unnamed: 0 Unnamed: 1    Fresh     Milk  Grocery  Frozen Detergents_Paper  \
# 2      Hotel     Lisbon   761233   228342   237542  184512            56081
# 3      Hotel     Oporto   326215    64519   123074  160861            13516
# 4      Hotel      Other  2928269   735753   820101  771606           165990
# 5     Retail     Lisbon    93600   194112   332495   46514           148055
# 6     Retail     Oporto   138506   174625   310200   29271           159795
# 7     Retail      Other  1032308  1153006  1675150  158886           724420
#
#   Delicatessen
# 2        70632
# 3        30965
# 4       320358
# 5        33695
# 6        23541
# 7       191752

# %%
redf=dropgrpdf.rename(columns = {'Unnamed: 0': 'Channel', 
                     'Unnamed: 1':'Region'})
                            
print(redf)
# Out:
#   Channel  Region    Fresh     Milk  Grocery  Frozen Detergents_Paper  \
# 2   Hotel  Lisbon   761233   228342   237542  184512            56081
# 3   Hotel  Oporto   326215    64519   123074  160861            13516
# 4   Hotel   Other  2928269   735753   820101  771606           165990
# 5  Retail  Lisbon    93600   194112   332495   46514           148055
# 6  Retail  Oporto   138506   174625   310200   29271           159795
# 7  Retail   Other  1032308  1153006  1675150  158886           724420
#
#   Delicatessen
# 2        70632
# 3        30965
# 4       320358
# 5        33695
# 6        23541
# 7       191752

# %%
redf.to_csv('D:/GL/SWDMAssignmentFinal/redata.csv')
redatadf=pd.read_csv('D:/GL/SWDMAssignmentFinal/redata.csv')
redatadf
# Out:
#    Unnamed: 0 Channel  Region    Fresh     Milk  Grocery  Frozen  \
# 0           2   Hotel  Lisbon   761233   228342   237542  184512
# 1           3   Hotel  Oporto   326215    64519   123074  160861
# 2           4   Hotel   Other  2928269   735753   820101  771606
# 3           5  Retail  Lisbon    93600   194112   332495   46514
# 4           6  Retail  Oporto   138506   174625   310200   29271
# 5           7  Retail   Other  1032308  1153006  1675150  158886
#
#    Detergents_Paper  Delicatessen
# 0             56081         70632
# 1             13516         30965
# 2            165990        320358
# 3            148055         33695
# 4            159795         23541
# 5            724420        191752

# %%
redatadf.sum(axis=0,skipna = True)
# Out:
# Unnamed: 0                                          27
# Channel              HotelHotelHotelRetailRetailRetail
# Region              LisbonOportoOtherLisbonOportoOther
# Fresh                                          5280131
# Milk                                           2550357
# Grocery                                        3498562
# Frozen                                         1351650
# Detergents_Paper                               1267857
# Delicatessen                                    670943
# dtype: object

# %%
redatadf1 = redatadf.drop(redatadf.columns[[0]], axis=1)
redatadf1
# Out:
#   Channel  Region    Fresh     Milk  Grocery  Frozen  Detergents_Paper  \
# 0   Hotel  Lisbon   761233   228342   237542  184512             56081
# 1   Hotel  Oporto   326215    64519   123074  160861             13516
# 2   Hotel   Other  2928269   735753   820101  771606            165990
# 3  Retail  Lisbon    93600   194112   332495   46514            148055
# 4  Retail  Oporto   138506   174625   310200   29271            159795
# 5  Retail   Other  1032308  1153006  1675150  158886            724420
#
#    Delicatessen
# 0         70632
# 1         30965
# 2        320358
# 3         33695
# 4         23541
# 5        191752

# %%
redatadf1.sum(axis=1,skipna = True)
# Out:
# 0    1538342
# 1     719150
# 2    5742077
# 3     848471
# 4     835938
# 5    4935522
# dtype: int64

# %%
# Summary total of 6 varieties by grouping channel and region
redatadf1['Sum row'] = redatadf1.sum(axis=1)
redatadf1.loc['Sum column'] = redatadf1.sum()
redatadf1
# Out:
#                                       Channel  \
# 0                                       Hotel
# 1                                       Hotel
# 2                                       Hotel
# 3                                      Retail
# 4                                      Retail
# 5                                      Retail
# Sum column  HotelHotelHotelRetailRetailRetail
#
#                                         Region    Fresh     Milk  Grocery  \
# 0                                       Lisbon   761233   228342   237542
# 1                                       Oporto   326215    64519   123074
# 2                                        Other  2928269   735753   820101
# 3                                       Lisbon    93600   194112   332495
# 4                                       Oporto   138506   174625   310200
# 5                                        Other  1032308  1153006  1675150
# Sum column  LisbonOportoOtherLisbonOportoOther  5280131  2550357  3498562
# ...

# %%
redatadf1.describe().T
# Out:
#                   count          mean           std       min       25%  \
# Fresh               7.0  1.508609e+06  1.927984e+06   93600.0  232360.5
# Milk                7.0  7.286734e+05  8.928230e+05   64519.0  184368.5
# Grocery             7.0  9.995891e+05  1.224931e+06  123074.0  273871.0
# Frozen              7.0  3.861857e+05  4.943925e+05   29271.0  102700.0
# Detergents_Paper    7.0  3.622449e+05  4.640459e+05   13516.0  102068.0
# Delicatessen        7.0  1.916980e+05  2.380346e+05   23541.0   32330.0
# Sum row             7.0  4.177000e+06  5.053574e+06  719150.0  842204.5
#
#                         50%        75%         max
# Fresh              761233.0  1980288.5   5280131.0
# Milk               228342.0   944379.5   2550357.0
# Grocery            332495.0  1247625.5   3498562.0
# Frozen             160861.0   478059.0   1351650.0
# Detergents_Paper   159795.0   445205.0   1267857.0
# Delicatessen        70632.0   256055.0    670943.0
# ...

# %%
#Trial check
moddf=redf.set_index(['Channel', 'Region'])
moddf
# Out:
#                   Fresh     Milk  Grocery  Frozen Detergents_Paper  \
# Channel Region
# Hotel   Lisbon   761233   228342   237542  184512            56081
#         Oporto   326215    64519   123074  160861            13516
#         Other   2928269   735753   820101  771606           165990
# Retail  Lisbon    93600   194112   332495   46514           148055
#         Oporto   138506   174625   310200   29271           159795
#         Other   1032308  1153006  1675150  158886           724420
#
#                Delicatessen
# Channel Region
# Hotel   Lisbon        70632
#         Oporto        30965
#         Other        320358
# Retail  Lisbon        33695
#         Oporto        23541
#         Other        191752

# %%
moddf.sum(axis = 0,skipna = True)
# Out:
# Fresh               7.612333e+36
# Milk                2.283426e+35
# Grocery             2.375421e+36
# Frozen              1.845122e+33
# Detergents_Paper    5.608114e+33
# Delicatessen        7.063231e+31
# dtype: float64

# %%
moddf.sum(axis = 1, skipna = True)
# Out:
# Channel  Region
# Hotel    Lisbon    7.612332e+33
#          Oporto    3.262156e+32
#          Other     2.928270e+36
# Retail   Lisbon    9.360019e+32
#          Oporto    1.385062e+33
#          Other     1.032308e+38
# dtype: float64

# %%
#Boxplot
sns.boxplot(data[['Milk', 'Fresh']])

# %%
#Entire Box plot
data.boxplot()

# %%
#Correlation
corr = data.corr()
corr
# Out:
#                   Buyer/Spender     Fresh      Milk   Grocery    Frozen  \
# Buyer/Spender          1.000000 -0.061151 -0.162290 -0.140509  0.053802
# Fresh                 -0.061151  1.000000  0.100510 -0.011854  0.345881
# Milk                  -0.162290  0.100510  1.000000  0.728335  0.123994
# Grocery               -0.140509 -0.011854  0.728335  1.000000 -0.040193
# Frozen                 0.053802  0.345881  0.123994 -0.040193  1.000000
# Detergents_Paper      -0.134365 -0.101953  0.661816  0.924641 -0.131525
# Delicatessen          -0.101845  0.244690  0.406368  0.205497  0.390947
#
#                   Detergents_Paper  Delicatessen
# Buyer/Spender            -0.134365     -0.101845
# Fresh                    -0.101953      0.244690
# Milk                      0.661816      0.406368
# Grocery                   0.924641      0.205497
# Frozen                   -0.131525      0.390947
# Detergents_Paper          1.000000      0.069291
# ...

# %%
#Correlation plot
sns.heatmap(corr, annot=True)

# %%
#Zscore plot
from scipy import stats
import matplotlib.pyplot as plot
def calcZscore(colname):
    Zscore=stats.zscore(data[colname])
    df=pd.DataFrame(Zscore)
    df.plot.kde()
    plot.title(colname+" Zscore")
    plot.show()
calcZscore('Fresh')

# %%
calcZscore('Milk')

# %%
calcZscore('Grocery')

# %%
calcZscore('Frozen')

# %%
calcZscore('Detergents_Paper')

# %%
calcZscore('Delicatessen')

# %%
#NormalDistPlot
from scipy.special import ndtri
import matplotlib.pyplot as plt
data['count']=data.index+1
n_rows=data.shape[0]
data['percentile area']=data['count']/n_rows
data['z_theoretical']=ndtri(data['percentile area'])

def normalplot(data,actualcolumn,columnname):
    data[actualcolumn]=(data[columnname]-data[columnname].mean())/data[columnname].std(ddof=0)
    plt.scatter(data[actualcolumn],data['z_theoretical'])
    plt.title(actualcolumn + " normal plot")
    plt.xlabel(actualcolumn)
    plt.ylabel("z_theoretical")            
    plt.plot([-2,-1,0,1,2],[-2,-1,0,1,2])
    plt.show()
    
normalplot(data,'z_actual_fresh','Fresh')
normalplot(data,'z_actual_milk','Milk')
normalplot(data,'z_actual_grocery','Grocery')
normalplot(data,'z_actual_frozen','Frozen')
normalplot(data,'z_actual_Detergents_Paper','Detergents_Paper')
normalplot(data,'z_actual_Delicatessen','Delicatessen')

# %%
#GaussianTest
from scipy.stats import shapiro
def gaussiantest(data,startindex):
    for i in range(startindex,len(data.columns)):
        stat, p = shapiro(data.iloc[:,i])
        print(data.columns.values[i]+ " p Value " + str(p))
        alpha = 0.05
        if p > alpha:
            print(' if the p value is greater than the chosen alpha level, then the null hypothesis that the data came from a normally distributed population can not be rejected')
        else:
            print('if the p value is less than the chosen alpha level, then the null hypothesis is rejected and there is evidence that the data tested are not normally distributed')

gaussiantest(data,3)
# Out:
# Fresh p Value 7.918285999464533e-24
# if the p value is less than the chosen alpha level, then the null hypothesis is rejected and there is evidence that the data tested are not normally distributed
# Milk p Value 9.762061919511109e-30
# if the p value is less than the chosen alpha level, then the null hypothesis is rejected and there is evidence that the data tested are not normally distributed
# Grocery p Value 3.9062091503225934e-28
# if the p value is less than the chosen alpha level, then the null hypothesis is rejected and there is evidence that the data tested are not normally distributed
# Frozen p Value 1.2913321191929252e-32
# if the p value is less than the chosen alpha level, then the null hypothesis is rejected and there is evidence that the data tested are not normally distributed
# Detergents_Paper p Value 1.9145929126306173e-30
# ...
